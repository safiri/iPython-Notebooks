# %%
print "Benvindo ao IPython. O notebook é muito fácil de usar!"
# Out:
# Benvindo ao IPython. O notebook é muito fácil de usar!

# %%
print "O IPython tem uma ótima calculadora!!! 2**100=", 2**100;
# Out:
# O IPython tem uma ótima calculadora!!! 2**100= 1267650600228229401496703205376

# %%
plot(rand(500));

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('upw-AIzWcfQ')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/upw-AIzWcfQ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c89d15c9bc7e> in <module>()
# ----> 1 n_c = output.expect[0]
#       2 n_a = output.expect[1]
#       3
#       4 fig, axes = subplots(1, 1, figsize=(8,6))
#       5
#
# NameError: name 'output' is not defined
